# %% [markdown]
# ## Docs
#
# 1. Given initial amount, specify split method and manipulation as one gets the best result
# 2. Run multiple times

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import plotly.plotly as py

# %% [markdown]
# ## General Funcs

# %%
def divergence(total,split):
    
    rand=np.random.random(split)
    
    randN = rand/np.sum(rand) # Normalized
    
    splitT = total*randN
    
    return splitT
    
    # print splitT, maxN
    
def evolution(total,split,mani,generation):
    
    evo = np.asarray([ np.amax(divergence(total,split)) ])
    
    newTotal = np.amax(divergence(total,split)) * mani
    
    for t in np.linspace(1,generation-1,generation-1):
        evo = np.append(evo,np.amax(divergence(newTotal,split)) )
        newTotal = np.amax(divergence(newTotal,split))*mani
        
    return evo

# %%
divergence(10,5)
# Out:
# array([ 4.31040584,  1.89881206,  0.19608559,  1.29608779,  2.29860872])

# %%
evolution(10,5,3,100)
# Out:
# array([   3.8054083 ,    3.27338833,    4.35566191,    2.72308311,
#           3.65963068,    5.10546739,   11.9155513 ,   10.6838239 ,
#          11.42978636,   15.98702859,   16.96413088,   18.24386944,
#          26.38039992,   46.29530701,   32.50555303,   32.31169227,
#          28.27702304,   54.81842407,   61.83121645,   56.52257853,
#          49.18102952,   58.13647545,   36.93539507,   64.80981394,
#          51.70022364,   36.67364554,   50.14656635,   53.73159027,
#          48.1814381 ,   90.97979137,  157.30097154,   96.94045335,
#          77.5127808 ,   80.96435268,   99.83285032,   79.05868032,
#          68.89441722,   73.62011293,  152.01850788,  111.22165695,
#         140.72069892,  116.49606123,  106.4362363 ,   96.65677906,
#          97.84725728,   89.91829876,  162.2761963 ,  134.96046336,
#          88.39930136,   76.09030472,   88.35741421,  129.28320854,
#         120.498367  ,  152.81592874,  181.91929251,  200.37979938,
#         138.72985844,  170.42845644,  173.42421354,  156.30629262,
#          88.61538203,  148.13240093,  120.21291974,  156.44473965,
#         187.27047204,  220.9493945 ,  192.16991751,  139.51183437,
#         116.50079948,  133.36369541,  159.57192502,  107.14041667,
#         126.66609797,   87.92086187,  211.2220564 ,  213.78567568,
#         150.42709285,  187.86280576,  137.57300408,  264.60855268,
#         158.20652504,  203.27173325,  132.67568341,  245.98180541,
#         393.84273849,  385.15440643,  174.85188953,  214.2038968 ,
#         227.23976725,  195.79667127,  311.28294444,  290.64933423,
#         335.53035408,  297.52766424,  328.13617062,  321.69945632,
#         168.54180327,  268.01111637,  247.72622627,  288.71783638])

# %% [markdown]
# ## Data

# %% [markdown]
# Run multiple times and compare data

# %%
data = np.asarray([])
for i in np.linspace(1,10,10):
    data =  np.append(data,evolution(10,5,3,100))  # 10： 初始数量; 5: 分几份; 3:得到最大的之后翻几倍；100：进行100轮

# %%
data = data.reshape( (10,100) )
runN = np.linspace(1,100,100)
runN.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(20,12.35))
plt.plot(runN,data[0],'g-', label = "Run # 1")
plt.plot(runN,data[1],'b-', label = "Run # 2")
plt.plot(runN,data[2],'r-', label = "Run # 3")
plt.plot(runN,data[3],'m-', label = "Run # 4")
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %% [markdown]
# Split:6

# %%
data2 = np.asarray([])
for i in np.linspace(1,10,10):
    data2 =  np.append(data2,evolution(10,6,3,100))  # 10： 初始数量; 6: 分6份; 3:得到最大的之后翻几倍；100：进行100轮

# %%
data2 = data2.reshape( (10,100) )
runN2 = np.linspace(1,100,100)
runN2.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(20,12.35))
plt.plot(runN2,data2[0],'g-', label = "Run # 1")
plt.plot(runN2,data2[1],'b-', label = "Run # 2")
plt.plot(runN2,data2[2],'r-', label = "Run # 3")
plt.plot(runN2,data2[3],'m-', label = "Run # 4")
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")
