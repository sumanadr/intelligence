# %% [markdown]
# ## Docs
#
# 1. Given initial amount, specify split method and manipulation as one gets the best result
# 2. Run multiple times
#
#
# 使用下面的这个部分来测试：[Take Home Examples](#takehome)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import plotly.plotly as py

# %% [markdown]
# ## General Funcs

# %%
def divergence(total,split):
    
    rand=np.random.random(split)
    
    randN = rand/np.sum(rand) # Normalized
    
    splitT = total*randN
    
    return splitT
    
    # print splitT, maxN
    
def evolution(total,split,mani,generation):
    
    evo = np.asarray([ np.amax(divergence(total,split)) ])
    
    newTotal = np.amax(divergence(total,split)) * mani
    
    for t in np.linspace(1,generation-1,generation-1):
        evo = np.append(evo,np.amax(divergence(newTotal,split)) )
        newTotal = np.amax(divergence(newTotal,split))*mani
        
    return evo

# %%
divergence(10,5)
# Out:
# array([ 0.11855313,  1.54336164,  1.93169619,  3.32355263,  3.08283641])

# %%
evolution(10,5,3,100)
# Out:
# array([  3.71005125,   4.38818206,   3.5369357 ,   4.19486422,
#          5.53230029,   5.02323035,   6.00229872,   5.82929876,
#          5.67090538,   3.61600534,   4.55485734,   2.82214783,
#          5.05270494,   5.44760251,   4.47514123,   3.82139833,
#          6.494836  ,   4.19219728,   4.40212207,   5.70447408,
#          3.90791313,   6.28367037,   4.03566584,   3.1028213 ,
#          4.05000492,   3.96867479,   5.08554725,   3.97782985,
#          3.91976431,   4.48319485,   7.06038578,   7.45268669,
#          7.62046584,   6.44548658,   4.73643269,   6.85898929,
#          7.6467058 ,   6.82899502,   7.44467523,   4.54865294,
#          3.51635688,   5.72790197,   5.81078827,   8.56026987,
#          6.14618873,   7.84631743,   5.69612759,   4.797756  ,
#          5.65972502,   5.05616395,   6.95837339,   7.75906877,
#          5.96521664,   4.53421119,   9.24339344,   7.97654061,
#          7.32817125,   6.89140733,   8.51737812,   6.04967663,
#         11.47714089,   5.69366275,   8.01997185,   9.23117437,
#          8.36107918,  11.76756005,   8.05173505,   8.19825731,
#          7.39829466,   8.68309092,   9.82180182,   7.00182381,
#         21.29469011,   8.85728008,   6.72544393,   9.44925174,
#          9.53533548,   7.07400634,  10.74414055,  13.23601386,
#         16.77901202,  14.05075709,  12.30151097,  25.8159249 ,
#         16.1302782 ,  13.12759298,  37.42895858,  34.83067189,
#         53.63601016,  54.36574312,  38.81909227,  35.43182382,
#         38.15397056,  43.75526883,  63.39455549,  53.1237706 ,
#         58.09123543,  60.43263601,  50.03631822,  81.88313652])

# %% [markdown]
# ## Data

# %% [markdown]
# Run multiple times and compare data

# %%
data = np.asarray([])
for i in np.linspace(1,10,10):
    data =  np.append(data,evolution(10,5,3,100))  # 10： 初始数量; 5: 分几份; 3:得到最大的之后翻几倍；100：进行100轮

# %%
data = data.reshape( (10,100) )
runN = np.linspace(1,100,100)
runN.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(20,12.35))
plt.plot(runN,data[0],'g-', label = "Run # 1")
plt.plot(runN,data[1],'b-', label = "Run # 2")
plt.plot(runN,data[2],'r-', label = "Run # 3")
plt.plot(runN,data[3],'m-', label = "Run # 4")
plt.plot(runN,data[4],'g--', label = "Run # 5")
plt.plot(runN,data[5],'b--', label = "Run # 6")

plt.legend()
plt.yscale('log')

plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %% [markdown]
# Split:6

# %%
data2 = np.asarray([])
for i in np.linspace(1,10,10):
    data2 =  np.append(data2,evolution(10,6,3,100))  # 10： 初始数量; 6: 分6份; 3:得到最大的之后翻几倍；100：进行100轮

# %%
data2 = data2.reshape( (10,100) )
runN2 = np.linspace(1,100,100)
runN2.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(20,12.35))
plt.plot(runN2,data2[0],'g-', label = "Run # 1")
plt.plot(runN2,data2[1],'b-', label = "Run # 2")
plt.plot(runN2,data2[2],'r-', label = "Run # 3")
plt.plot(runN2,data2[3],'m-', label = "Run # 4")
plt.yscale('log')
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %%
# write a new function
def game(init,split,mani,gen,run):
    dataGame = np.asarray([])
    
    for i in np.linspace(1,run,run):
        dataGame=np.append(dataGame,evolution(init,split,mani,gen))
        
    dataGame = dataGame.reshape( (run,gen) )
    # genN = np.linspace(1,gen,gen)
    
    return dataGame

# %%
game(0.5,5,3,20,5)
# Out:
# array([[ 0.17906471,  0.19493499,  0.15533317,  0.23941023,  0.25777588,
#          0.22124889,  0.14145832,  0.11705145,  0.1742976 ,  0.3436827 ,
#          0.17655582,  0.12398234,  0.21573605,  0.10865581,  0.14624601,
#          0.17650138,  0.14514094,  0.1006232 ,  0.24360983,  0.14206947],
#        [ 0.14976002,  0.2233958 ,  0.2564325 ,  0.19526956,  0.20449266,
#          0.15793698,  0.24698268,  0.53779576,  0.32257703,  0.2653487 ,
#          0.3624494 ,  0.8239049 ,  0.37969174,  0.3627169 ,  0.41568512,
#          0.28655135,  0.57143139,  0.30906619,  0.20279078,  0.36079095],
#        [ 0.15237654,  0.2118871 ,  0.1837852 ,  0.16415786,  0.22960612,
#          0.30064742,  0.17453171,  0.15258019,  0.18551513,  0.31023577,
#          0.13457461,  0.12502803,  0.13374382,  0.15185019,  0.10438564,
#          0.15405388,  0.10125809,  0.1108191 ,  0.0742036 ,  0.05926177],
#        [ 0.24622278,  0.11032544,  0.15056288,  0.0834476 ,  0.0775143 ,
#          0.18790607,  0.1004669 ,  0.15770886,  0.11959836,  0.10879881,
#          0.17454758,  0.2997015 ,  0.2153783 ,  0.34874245,  0.87159841,
#          0.39792631,  0.35668705,  0.40678771,  0.53039628,  0.36416195],
#        [ 0.14764793,  0.25387402,  0.16258515,  0.13289889,  0.17312554,
#          0.18235746,  0.18552848,  0.1743296 ,  0.23488975,  0.2368613 ,
#          0.16701551,  0.19588118,  0.13795897,  0.12455604,  0.16347066,
#          0.35701877,  0.27524951,  0.23248672,  0.22462348,  0.19110836]])

# %% [markdown]
# <a id="takehome"></a>
# -----
# ## Take Home Examples

# %%
pltData = game(0.5,5,3,20,5) # 0.5: 起始值；5：分五份；3：翻3倍；20：进行20轮；5进行五次重复实验
genData = np.linspace(1,20,20) # 20 generations，改了上面的 20 ，这里也要改。

plt.figure(figsize=(20,12.35))
plt.plot(genData,pltData[0],'g-', label = "Run # 1")
plt.plot(genData,pltData[1],'b-', label = "Run # 2")
plt.plot(genData,pltData[2],'r-', label = "Run # 3")
plt.plot(genData,pltData[3],'m-', label = "Run # 4")
plt.yscale('log')
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %% [markdown]
# ## Phase Diagram

# %% [markdown]
# Check the population left in certain runs.

# %%
maxData = np.asarray([])
for i in np.linspace(1,10,10):
    maxData = np.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-1cbf51577705> in <module>()
#       1 maxData = np.asarray([])
#       2 for i in np.linspace(1,10,10):
# ----> 3     maxData = np.append()
#
# TypeError: append() takes at least 2 arguments (0 given)
