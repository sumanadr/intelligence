# %% [markdown]
# ## Docs
#
# 1. Given initial amount, specify split method and manipulation as one gets the best result
# 2. Run multiple times
#
#
# 使用下面的这个部分来测试：[Take Home Examples](#takehome)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

# %% [markdown]
# Data

# %%
print 'triple5'
tls.embed("https://plot.ly/~emptymalei/121")
# Out:
# triple5
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~emptymalei/121.embed" height="525" width="100%"></iframe>

# %%
print 'triple6'
tls.embed("https://plot.ly/~emptymalei/119")
# Out:
# triple6
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~emptymalei/119.embed" height="525" width="100%"></iframe>

# %% [markdown]
# ## General Funcs

# %%
def divergence(total,split):
    
    rand=np.random.random(split)
    
    randN = rand/np.sum(rand) # Normalized
    
    splitT = total*randN
    
    return splitT
    
    # print splitT, maxN
    
def evolution(total,split,mani,generation):
    
    evo = np.asarray([ np.amax(divergence(total,split)) ])
    
    newTotal = np.amax(divergence(total,split)) * mani
    
    for t in np.linspace(1,generation-1,generation-1):
        evo = np.append(evo,np.amax(divergence(newTotal,split)) )
        newTotal = np.amax(divergence(newTotal,split))*mani
        
    return evo

# %%
divergence(10,5)
# Out:
# array([ 1.54265819,  3.46060696,  2.99085146,  2.00166399,  0.00421939])

# %%
evolution(10,5,3,100)
# Out:
# array([ 3.84485815,  3.04123639,  3.97144532,  2.61180451,  2.42242127,
#         2.16078269,  1.60196245,  3.08022903,  1.8809271 ,  2.33421429,
#         2.56761236,  1.67047349,  1.70102338,  1.96199128,  1.58211342,
#         1.40478396,  1.15593136,  1.94165043,  1.94449295,  1.92203877,
#         1.50292356,  1.35828544,  1.64523225,  1.30682403,  1.35731371,
#         1.9523099 ,  1.56225853,  3.7977764 ,  4.04097694,  4.08570867,
#         3.34924005,  2.78734084,  2.59121994,  2.34709988,  1.78008602,
#         2.05594845,  1.76631737,  2.58483453,  2.03409565,  3.04618136,
#         1.84815167,  1.89807473,  1.66829989,  1.54098298,  2.44369751,
#         1.85990214,  2.78881087,  1.39938529,  1.30428333,  1.38764672,
#         0.89806124,  0.98481967,  1.31636067,  0.96235353,  0.68006069,
#         0.89245856,  0.49786108,  0.67830661,  1.06276063,  0.87227496,
#         1.55358327,  1.19122425,  1.23375994,  0.90726489,  0.93234397,
#         0.79758682,  1.12653949,  0.85029866,  1.45438764,  1.12176085,
#         1.31491996,  1.1983889 ,  0.96583319,  0.88178291,  1.73396443,
#         0.91039592,  1.05421514,  1.59318195,  0.92445934,  1.30227814,
#         1.35528632,  0.80635613,  0.66731239,  0.95990509,  0.7091514 ,
#         1.19972085,  1.9640819 ,  2.43780684,  1.70929162,  1.6129323 ,
#         1.42750803,  2.09257273,  1.22408303,  1.68439722,  1.20267799,
#         1.16922721,  2.02791696,  1.35188177,  1.35916245,  1.23844611])

# %% [markdown]
# ## Data

# %% [markdown]
# Run multiple times and compare data

# %%
data = np.asarray([])
for i in np.linspace(1,10,10):
    data =  np.append(data,evolution(10,5,3,100))  # 10： 初始数量; 5: 分几份; 3:得到最大的之后翻几倍；100：进行100轮

# %%
data = data.reshape( (10,100) )
runN = np.linspace(1,100,100)
runN.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(20,12.35))
plt.plot(runN,data[0],'g-', label = "Run # 1")
plt.plot(runN,data[1],'b-', label = "Run # 2")
plt.plot(runN,data[2],'r-', label = "Run # 3")
plt.plot(runN,data[3],'m-', label = "Run # 4")
plt.plot(runN,data[4],'g--', label = "Run # 5")
plt.plot(runN,data[5],'b--', label = "Run # 6")

plt.legend()
# plt.yscale('log')

plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %% [markdown]
# Split:6

# %%
data2 = np.asarray([])
for i in np.linspace(1,10,10):
    data2 =  np.append(data2,evolution(10,6,3,100))  # 10： 初始数量; 6: 分6份; 3:得到最大的之后翻几倍；100：进行100轮

# %%
data2 = data2.reshape( (10,100) )
runN2 = np.linspace(1,100,100)
runN2.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(20,12.35))
plt.plot(runN2,data2[0],'g-', label = "Run # 1")
plt.plot(runN2,data2[1],'b-', label = "Run # 2")
plt.plot(runN2,data2[2],'r-', label = "Run # 3")
plt.plot(runN2,data2[3],'m-', label = "Run # 4")
plt.yscale('log')
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %%
# write a new function
def game(init,split,mani,gen,run):
    dataGame = np.asarray([])
    
    for i in np.linspace(1,run,run):
        dataGame=np.append(dataGame,evolution(init,split,mani,gen))
        
    dataGame = dataGame.reshape( (run,gen) )
    # genN = np.linspace(1,gen,gen)
    
    return dataGame

# %%
game(0.5,5,3,20,5)
# Out:
# array([[ 0.23147451,  0.13070251,  0.15795318,  0.34981659,  0.28969991,
#          0.22490913,  0.26737367,  0.24807903,  0.27246498,  0.26977319,
#          0.36333236,  0.34768943,  0.43719148,  0.2823755 ,  0.53918148,
#          0.30052755,  0.28150643,  0.33298271,  0.46532751,  0.55426604],
#        [ 0.16992963,  0.23596185,  0.20712899,  0.18603116,  0.15873456,
#          0.20008105,  0.24361633,  0.16880374,  0.32591888,  0.25754015,
#          0.30508986,  0.29190276,  0.33247634,  0.19545232,  0.18531134,
#          0.255976  ,  0.36483788,  1.00448213,  0.61222071,  0.81376642],
#        [ 0.13686223,  0.16011841,  0.16486213,  0.10266101,  0.07406112,
#          0.08824398,  0.08323953,  0.10965767,  0.08214698,  0.08164818,
#          0.09656292,  0.10475062,  0.09121979,  0.06607402,  0.07886   ,
#          0.12846873,  0.1168921 ,  0.10673893,  0.10333927,  0.10104461],
#        [ 0.1777086 ,  0.1026987 ,  0.08132686,  0.07822162,  0.07258843,
#          0.07421305,  0.08310726,  0.15724704,  0.11456549,  0.09832805,
#          0.08987968,  0.20613776,  0.17070481,  0.35038699,  0.58518925,
#          0.52325029,  0.48346797,  0.52960309,  0.36686534,  0.38848691],
#        [ 0.14158564,  0.22166193,  0.21299506,  0.15867463,  0.21130505,
#          0.29096416,  0.17552247,  0.1970061 ,  0.15148041,  0.11064581,
#          0.15209083,  0.17950984,  0.08593346,  0.08523738,  0.09651758,
#          0.10180625,  0.10879583,  0.10352365,  0.09008986,  0.1068733 ]])

# %% [markdown]
# <a id="takehome"></a>
# -----
# ## Take Home Examples

# %%
pltData = game(0.5,5,3,20,5) # 0.5: 起始值；5：分五份；3：翻3倍；20：进行20轮；5进行五次重复实验
genData = np.linspace(1,20,20) # 20 generations，改了上面的 20 ，这里也要改。

plt.figure(figsize=(20,12.35))
plt.plot(genData,pltData[0],'g-', label = "Run # 1")
plt.plot(genData,pltData[1],'b-', label = "Run # 2")
plt.plot(genData,pltData[2],'r-', label = "Run # 3")
plt.plot(genData,pltData[3],'m-', label = "Run # 4")
# plt.yscale('log')
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %%
pltData = game(0.5,6,3,100,5) # 0.5: 起始值；5：分6份；3：翻3倍；20：进行20轮；5进行五次重复实验
genData = np.linspace(1,100,100) # 20 generations，改了上面的 20 ，这里也要改。

plt.figure(figsize=(20,12.35))
plt.plot(genData,pltData[0],'g-', label = "Run # 1")
plt.plot(genData,pltData[1],'b-', label = "Run # 2")
plt.plot(genData,pltData[2],'r-', label = "Run # 3")
plt.plot(genData,pltData[3],'m-', label = "Run # 4")
# plt.yscale('log')
plt.legend()
plt.show()

# py.iplot_mpl(plt.gcf(),filename="evolutionSim100")

# %% [markdown]
# ## Phase Diagram

# %% [markdown]
# Check the population left in certain runs.

# %%
maxData = np.asarray([])
for i in np.linspace(1,10,10):
    maxData = np.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1cbf51577705> in <module>()
#       1 maxData = np.asarray([])
#       2 for i in np.linspace(1,10,10):
# ----> 3     maxData = np.append()
#
# TypeError: append() takes at least 2 arguments (0 given)
